# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
icecream = pd.read_csv("https://github.com/YBIFoundation/Dataset/raw/main/Ice%20Cream.csv")
icecream
# Out:
#      Temperature  Revenue
# 0           24.6      535
# 1           26.1      626
# 2           27.8      661
# 3           20.6      488
# 4           11.6      317
# ..           ...      ...
# 495         22.3      525
# 496         32.9      756
# 497         12.6      307
# 498         22.4      567
# 499         29.0      656
#
# [500 rows x 2 columns]

# %%
icecream.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
icecream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
icecream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
icecream.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
icecream.shape
# Out:
# (500, 2)

# %%
x = icecream[['Temperature']]
y = icecream['Revenue']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size = 0.7, random_state = 2529)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# %%
print("mean_absolute_percentage_error = ", mean_absolute_percentage_error(y_test, y_pred))
print("mean_absolute_error = ", mean_absolute_error(y_test, y_pred))
print("mean_squared_error = ", mean_squared_error(y_test, y_pred))
# Out:
# mean_absolute_percentage_error =  0.042214848219420134
# mean_absolute_error =  19.138687444270737
# mean_squared_error =  583.7362763558341

# %% [markdown]
# ---

# %% [markdown]
# # **ENHANCEMENT SUGGESTED BY CHATGPT**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
import matplotlib.pyplot as plt

# Load data
url = "https://github.com/YBIFoundation/Dataset/raw/main/Ice%20Cream.csv"
icecream = pd.read_csv(url)

# Explore data
icecream.head()
icecream.info()
icecream.describe()
icecream.columns
icecream.shape

# Visualize the relationship between temperature and revenue
plt.scatter(icecream['Temperature'], icecream['Revenue'])
plt.title('Temperature vs Revenue')
plt.xlabel('Temperature')
plt.ylabel('Revenue')
plt.show()

# Prepare data
x = icecream[['Temperature']]
y = icecream['Revenue']

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=2529)

# Model training
model = LinearRegression()
model.fit(x_train, y_train)

# Predictions
y_pred = model.predict(x_test)

# Model evaluation
print("mean_absolute_percentage_error =", mean_absolute_percentage_error(y_test, y_pred))
print("mean_absolute_error =", mean_absolute_error(y_test, y_pred))
print("mean_squared_error =", mean_squared_error(y_test, y_pred))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB
# mean_absolute_percentage_error = 0.042214848219420134
# mean_absolute_error = 19.138687444270737
# mean_squared_error = 583.7362763558341
